# %% [markdown]
# <a href="https://colab.research.google.com/github/arikinhafln/data-analytics-activities/blob/main/Desafio_Forbes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Desafio 5: Forbes**
#
# Definição do problema: Você está trabalhando em um jornal e o
# editor quer que você responda as seguintes questões:
# 1. Qual a empresa mais valiosa da lista da Forbes 2000?
# 2. Construa uma tabela com as TOP 10 empresas mais lucrativas da
# lista.
# 3. Qual a média de valores de empresa das cinco categorias mais
# valiosas? *texto em itálico*

# %%
import pandas as pd
import numpy as np

# %%
df_forber = pd.read_csv('/content/Forbes2000.csv')
df.head()
# Out:
#    rownames  rank                 name         country              category  \
# 0         1     1            Citigroup   United States               Banking
# 1         2     2     General Electric   United States         Conglomerates
# 2         3     3  American Intl Group   United States             Insurance
# 3         4     4           ExxonMobil   United States  Oil & gas operations
# 4         5     5                   BP  United Kingdom  Oil & gas operations
#
#     sales  profits   assets  marketvalue
# 0   94.71    17.85  1264.03       255.30
# 1  134.19    15.59   626.93       328.54
# 2   76.66     6.46   647.66       194.87
# 3  222.88    20.96   166.99       277.02
# 4  232.57    10.27   177.57       173.54

# %%
# 1 Qual a empresa mais valiosa da lista da Forbes 2000?
empresa_mais_valiosa = df_forber['marketvalue'].max()
empresa_mais_valiosa
# Out:
# 328.54

# %%
# 2. Construa uma tabela com as TOP 10 empresas mais lucrativas da lista.
top_10_empresas_mais_valiosas = df.nlargest(10, 'profits')[['name', 'profits']]
top_10_empresas_mais_valiosas
# Out:
#                 name  profits
# 3         ExxonMobil    20.96
# 0          Citigroup    17.85
# 1   General Electric    15.59
# 5    Bank of America    10.81
# 4                 BP    10.27
# 19       Freddie Mac    10.09
# 21      Altria Group     9.20
# 9    Wal-Mart Stores     9.05
# 30         Microsoft     8.88
# 16             Total     8.84

# %%
# 3 Qual a média de valores de empresa das cinco categorias mais valiosas?
media_categoria = df_forber.groupby('category')['marketvalue'].mean()
media_categoria.sort_values(ascending=False)[0:5]
# Out:
# category
# Drugs & biotechnology          39.200000
# Conglomerates                  25.874194
# Semiconductors                 23.911538
# Software & services            22.613226
# Telecommunications services    21.857015
# Name: marketvalue, dtype: float64
