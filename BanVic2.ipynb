# %% [markdown]
# <a href="https://colab.research.google.com/github/arikinhafln/data-analytics-activities/blob/main/BanVic2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Carregando tabela
agencia = pd.read_csv('/agencias.csv')
clientes = pd.read_csv('/clientes.csv')
contas = pd.read_csv('/contas.csv')
transacoes = pd.read_csv('/transacoes.csv')

# Merge
df_banco = pd.merge(contas, clientes, on='cod_cliente', how='left')
df_final = pd.merge(transacoes, df_banco, on='num_conta', how='inner')
df_final.head(10)
# Out:
#    cod_transacao  num_conta           data_transacao nome_transacao  \
# 0           3100        256  2020-05-22 03:15:21 UTC          Saque
# 1          28405        256  2021-06-29 11:52:38 UTC          Saque
# 2           1776        512  2020-05-17 13:04:50 UTC          Saque
# 3          14311        512  2020-09-06 02:55:34 UTC          Saque
# 4          25012        512  2020-10-16 09:26:52 UTC          Saque
# 5          26883        512  2020-11-09 00:47:27 UTC          Saque
# 6          35017        512  2021-04-13 08:17:24 UTC          Saque
# 7          46264        512  2021-05-01 06:25:50 UTC          Saque
# 8          21340        768  2020-02-14 21:42:15 UTC          Saque
# 9          64259          1  2019-08-11 15:13:07 UTC          Saque
#
#    valor_transacao  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0           -130.0          256            7               84         PF
# 1           -255.0          256            7               84         PF
# 2           -250.0          512            9               90         PF
# 3            -80.0          512            9               90         PF
# 4           -475.0          512            9               90         PF
# 5           -210.0          512            9               90         PF
# 6            -50.0          512            9               90         PF
# 7          -1160.0          512            9               90         PF
# 8           -170.0          768            2               22         PF
# 9           -245.0            1            5               10         PF
#
#              data_abertura  ...   data_ultimo_lancamento  primeiro_nome  \
# 0  2020-04-28 16:46:00 UTC  ...  2022-11-02 17:44:43 UTC         Agatha
# 1  2020-04-28 16:46:00 UTC  ...  2022-11-02 17:44:43 UTC         Agatha
# 2  2020-05-12 12:40:00 UTC  ...  2022-02-06 14:04:31 UTC        Vitória
# 3  2020-05-12 12:40:00 UTC  ...  2022-02-06 14:04:31 UTC        Vitória
# 4  2020-05-12 12:40:00 UTC  ...  2022-02-06 14:04:31 UTC        Vitória
# 5  2020-05-12 12:40:00 UTC  ...  2022-02-06 14:04:31 UTC        Vitória
# 6  2020-05-12 12:40:00 UTC  ...  2022-02-06 14:04:31 UTC        Vitória
# 7  2020-05-12 12:40:00 UTC  ...  2022-02-06 14:04:31 UTC        Vitória
# 8  2019-04-22 14:34:00 UTC  ...  2022-12-29 23:55:59 UTC        Anthony
# 9  2014-07-08 16:25:00 UTC  ...  2022-11-08 13:22:46 UTC          Vitor
#
#   ultimo_nome                             email tipo_cliente  \
# 0    Oliveira         monteirosofia@example.net           PF
# 1    Oliveira         monteirosofia@example.net           PF
# 2      Fogaça  teixeiraluiz-gustavo@example.net           PF
# 3      Fogaça  teixeiraluiz-gustavo@example.net           PF
# 4      Fogaça  teixeiraluiz-gustavo@example.net           PF
# 5      Fogaça  teixeiraluiz-gustavo@example.net           PF
# 6      Fogaça  teixeiraluiz-gustavo@example.net           PF
# 7      Fogaça  teixeiraluiz-gustavo@example.net           PF
# 8    da Costa             wcarvalho@example.net           PF
# 9     Peixoto       ferreiradaniela@example.com           PF
#
#              data_inclusao         cpfcnpj data_nascimento  \
# 0  2020-04-28 16:46:00 UTC  896.130.725-86      1982-01-26
# 1  2020-04-28 16:46:00 UTC  896.130.725-86      1982-01-26
# 2  2020-05-12 12:40:00 UTC  260.145.378-80      2005-06-05
# 3  2020-05-12 12:40:00 UTC  260.145.378-80      2005-06-05
# 4  2020-05-12 12:40:00 UTC  260.145.378-80      2005-06-05
# 5  2020-05-12 12:40:00 UTC  260.145.378-80      2005-06-05
# 6  2020-05-12 12:40:00 UTC  260.145.378-80      2005-06-05
# 7  2020-05-12 12:40:00 UTC  260.145.378-80      2005-06-05
# 8  2019-04-22 14:34:00 UTC  305.692.847-83      1981-09-30
# 9  2014-07-08 16:25:00 UTC  475.916.830-39      1993-09-27
#
#                                             endereco        cep
# 0  Recanto Bernardo Rezende, 11 São Damião 25575-...  50987-872
# 1  Recanto Bernardo Rezende, 11 São Damião 25575-...  50987-872
# 2  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 3  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 4  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 5  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 6  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 7  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
#
# 0      896.130.725-86      1982-01-26
# 1      896.130.725-86      1982-01-26
# 2      260.145.378-80      2005-06-05
# 3      260.145.378-80      2005-06-05
# 4      260.145.378-80      2005-06-05
# ...               ...             ...
# 71994  304.867.925-10      1961-10-30
# 71995  304.867.925-10      1961-10-30
# 71996  507.689.421-01      1962-11-15
# 71997  943.170.528-14      1974-05-01
# 71998  943.170.528-14      1974-05-01
#
#                                                 endereco        cep
# 0      Recanto Bernardo Rezende, 11 São Damião 25575-...  50987-872
# 1      Recanto Bernardo Rezende, 11 São Damião 25575-...  50987-872
# 2      Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 3      Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 4      Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# ...                                                  ...        ...
# 71994  Fazenda de Dias, 1 Marajó 72368-137 da Conceiç...  92971-218
# 71995  Fazenda de Dias, 1 Marajó 72368-137 da Conceiç...  92971-218
# 71996  Campo Nunes, 35 Calafate 93091-401 Moura Grand...  29657-764
# 71997  Área de da Rosa, 58 Estrela Do Oriente 08916-9...   66310967
# 71998  Área de da Rosa, 58 Estrela Do Oriente 08916-9...   66310967
#
# [71999 rows x 22 columns]

# %%
# Definir o intervalo de datas baseado nos dados do BanVic
data_min = df_final['data_transacao'].min()
data_max = df_final['data_transacao'].max()

# Criar a dim_dates
dim_dates = pd.DataFrame({'data': pd.date_range(start=data_min, end=data_max)})

# Adicionar atributos exigidos pelo desafio
dim_dates['ano'] = dim_dates['data'].dt.year
dim_dates['mes'] = dim_dates['data'].dt.month
dim_dates['dia_da_semana'] = dim_dates['data'].dt.day_name() # Para responder à média de transações
dim_dates['nome_mes'] = dim_dates['data'].dt.month_name()

# Validar a afirmação do analista sobre meses pares vs ímpares
dim_dates['mes_par'] = dim_dates['mes'] % 2 == 0

print(dim_dates.head())
# Out:
#                        data   ano  mes dia_da_semana  nome_mes  mes_par
# 0 2010-02-27 16:39:46+00:00  2010    2      Saturday  February     True
# 1 2010-02-28 16:39:46+00:00  2010    2        Sunday  February     True
# 2 2010-03-01 16:39:46+00:00  2010    3        Monday     March    False
# 3 2010-03-02 16:39:46+00:00  2010    3       Tuesday     March    False
# 4 2010-03-03 16:39:46+00:00  2010    3     Wednesday     March    False

# %%
import pandas as pd

# 1. Converter data de abertura da conta
# (Ajuste o nome da coluna conforme o seu arquivo, ex: 'data_abertura')
contas['data_abertura'] = pd.to_datetime(contas['data_abertura'], errors='coerce')

# 2. Ordenar clientes dos mais antigos para os mais novos
contas_ordenadas = contas.sort_values(by='data_abertura')

print("Clientes mais antigos (Top 50):")
print(contas_ordenadas[['num_conta', 'data_abertura']].head(50))
# Out:
# Clientes mais antigos (Top 50):
#      num_conta             data_abertura
# 93         382 2010-02-02 14:28:00+00:00
# 55           6 2010-03-09 12:09:00+00:00
# 23         242 2010-05-06 14:03:00+00:00
# 56         620 2010-06-21 16:42:00+00:00
# 73         146 2010-06-27 10:33:00+00:00
# 195        972 2010-08-10 15:41:00+00:00
# 72         106 2010-08-14 15:55:00+00:00
# 126         85 2010-10-04 13:19:00+00:00
# 187         11 2010-11-12 16:37:00+00:00
# 168         62 2010-12-02 12:14:00+00:00
# 53         631 2010-12-10 15:06:00+00:00
# 151        435 2011-02-02 11:14:00+00:00
# 78         347 2011-02-03 16:40:00+00:00
# 60         559 2011-02-05 14:40:00+00:00
# 18         741    2012-03-03
# 157        821    2012-03-12
# 202        510    2012-03-16
# 164        744    2012-03-21
# 230        376    2012-04-07
# 13         954    2012-04-15
# 189        244    2012-04-20
# 289        298    2012-04-21
# 242        525    2012-05-03
# 140        750    2012-05-05

# %%
# Substitua 'valor_transacao' pelo nome real da coluna de valor no seu dataset
volume_por_conta = transacoes.groupby('num_conta')['valor_transacao'].sum().reset_index()

# Unir (Merge) o volume transacionado com a tabela de contas (que já está com a data limpa)
df_analise = pd.merge(contas, volume_por_conta, on='num_conta', how='left')

# Preencher com 0 as contas que nunca transacionaram
df_analise['valor_transacao'] = df_analise['valor_transacao'].fillna(0)

# Criar uma métrica de "Anos de Conta" para facilitar a visualização
# Precisamos converter de volta para datetime para calcular a diferença
hoje = pd.to_datetime('today')
df_analise['data_abertura_dt'] = pd.to_datetime(df_analise['data_abertura'])
df_analise['anos_de_conta'] = (hoje - df_analise['data_abertura_dt']).dt.days // 365

# Agrupar por ano de abertura para ver a média de transação por "safra" de clientes
ranking_antiguidade = df_analise.groupby('anos_de_conta')['valor_transacao'].mean().sort_index(ascending=False)

print("Média de Volume Transacionado por Tempo de Casa (Anos):")
print(ranking_antiguidade)
# Out:
# Média de Volume Transacionado por Tempo de Casa (Anos):
# anos_de_conta
# 15    32786.861818
# 14    37819.715000
# 13    28211.280000
# 12    43867.942273
# 11    22106.396250
# 10    27013.746029
# 9     23901.657600
# 8     26575.006211
# 7     28405.802549
# 6     23770.288036
# 5     32743.650811
# 4     18791.097826
# 3     18506.389559
# Name: valor_transacao, dtype: float64

# %%
df_final
# Out:
#        cod_transacao  num_conta                  data_transacao  \
# 0               3100        256         2020-05-22 03:15:21 UTC
# 1              28405        256         2021-06-29 11:52:38 UTC
# 2               1776        512         2020-05-17 13:04:50 UTC
# 3              14311        512         2020-09-06 02:55:34 UTC
# 4              25012        512         2020-10-16 09:26:52 UTC
# ...              ...        ...                             ...
# 71994          17007        764  2022-12-29 23:59:59.746608 UTC
# 71995          22320        764  2022-12-29 23:59:59.055028 UTC
# 71996           8697        509         2012-05-07 13:45:41 UTC
# 71997          11574        766         2015-09-19 05:13:07 UTC
# 71998          64396        766  2022-12-29 23:59:59.607373 UTC
#
#                          nome_transacao  valor_transacao  cod_cliente  \
# 0                                 Saque           -130.0          256
# 1                                 Saque           -255.0          256
# 2                                 Saque           -250.0          512
# 3                                 Saque            -80.0          512
# 4                                 Saque           -475.0          512
# ...                                 ...              ...          ...
# 71994  Transferência entre CC - Crédito             82.3          764
# 71995  Transferência entre CC - Crédito            414.8          764
# 71996  Transferência entre CC - Crédito            720.4          509
# 71997  Transferência entre CC - Crédito           1143.0          766
# 71998  Transferência entre CC - Crédito            420.7          766
#
#        cod_agencia  cod_colaborador tipo_conta            data_abertura  ...  \
# 0                7               84         PF  2020-04-28 16:46:00 UTC  ...
# 1                7               84         PF  2020-04-28 16:46:00 UTC  ...
# 2                9               90         PF  2020-05-12 12:40:00 UTC  ...
# 3                9               90         PF  2020-05-12 12:40:00 UTC  ...
# 4                9               90         PF  2020-05-12 12:40:00 UTC  ...
# 1           -255.0          256            7               84         PF
# 2           -250.0          512            9               90         PF
# 3            -80.0          512            9               90         PF
# 4           -475.0          512            9               90         PF
#
#              data_abertura  ...  primeiro_nome  ultimo_nome  \
# 0  2020-04-28 16:46:00 UTC  ...         Agatha     Oliveira
# 1  2020-04-28 16:46:00 UTC  ...         Agatha     Oliveira
# 2  2020-05-12 12:40:00 UTC  ...        Vitória       Fogaça
# 3  2020-05-12 12:40:00 UTC  ...        Vitória       Fogaça
# 4  2020-05-12 12:40:00 UTC  ...        Vitória       Fogaça
#
#                               email tipo_cliente            data_inclusao  \
# 0         monteirosofia@example.net           PF  2020-04-28 16:46:00 UTC
# 1         monteirosofia@example.net           PF  2020-04-28 16:46:00 UTC
# 2  teixeiraluiz-gustavo@example.net           PF  2020-05-12 12:40:00 UTC
# 3  teixeiraluiz-gustavo@example.net           PF  2020-05-12 12:40:00 UTC
# 4  teixeiraluiz-gustavo@example.net           PF  2020-05-12 12:40:00 UTC
#
#           cpfcnpj data_nascimento  \
# 0  896.130.725-86      1982-01-26
# 1  896.130.725-86      1982-01-26
# 2  260.145.378-80      2005-06-05
# 3  260.145.378-80      2005-06-05
# 4  260.145.378-80      2005-06-05
#
#                                             endereco        cep  \
# 0  Recanto Bernardo Rezende, 11 São Damião 25575-...  50987-872
# 1  Recanto Bernardo Rezende, 11 São Damião 25575-...  50987-872
# 2  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 3  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
# 4  Via Noah Fernandes, 78 Tres Marias 69283-118 M...  86720-928
#
#      nome_completo
# 0  Agatha Oliveira
# 1  Agatha Oliveira
# 2   Vitória Fogaça
# 3   Vitória Fogaça
# 4   Vitória Fogaça
#
# [5 rows x 23 columns]

# %%
# Agrupamos por número da conta e somamos o valor
volume_por_conta = transacoes.groupby('num_conta')['valor_transacao'].sum().reset_index()
volume_por_conta.head(50)
# Out:
#     num_conta  valor_transacao
# 0           1         22538.06
# 1           2            12.72
# 2           3         24079.04
# 3           4        170283.25
# 4           5        120169.19
# 5           6         13407.48
# 6           7            23.43
# 7           8          1054.95
# 8           9         75739.07
# 9          10         28682.48
# 10         11          8414.48
# 11         12           405.41
# 12         13           212.50
# 13         14          3491.48
# 14         15          3218.29
# 15         16          2132.85
# 16         17           237.60
# 17         18        217787.98
# 18         19          2364.85
# 19         20         49629.64
# 20         21          6957.31
# 21         22           103.16
# 22         23         19299.27
# 23         24         34541.16
# 24         25          9647.99
# 25         26         10032.94
# 26         27           228.68
# 27         28         50324.19
# 28         29            26.34
# 29         30           957.15
# 30         31         20280.68
# 31         32         16884.65
# 32         33         10887.28
# 33         34         29187.79
# 34         35         44817.87
# 35         36         40313.21
# 36         37           328.26
# 37         38         31765.42
# 38         39         12760.23
# 39         40           164.31
# 40         41            91.53
# 41         42         27609.02
# 42         43         39429.83
# 43         44         24401.26
# 44         45         13450.80
# 45         46        151644.40
# 46         47         35527.59
# 47         48          2366.42
# 48         49            97.49
# 49         50            92.12

# %%
# Cruzar Contas com Volume de Transações
df_final = pd.merge(contas, volume_por_conta, on='num_conta', how='left')
df_final['valor_transacao'] = df_final['valor_transacao'].fillna(0) # Clientes sem transação = 0
df_final.head()
# Out:
#    num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0         53           53            1                7         PF
# 1        190          190            1                7         PF
# 2        191          191            1                7         PF
# 3        203          203            1                7         PF
# 4        254          254            1                7         PF
#
#   data_abertura  saldo_total  saldo_disponivel   data_ultimo_lancamento  \
# 0    2011-05-24    2984.7615           2814.67  2019-07-02 11:03:46 UTC
# 1    2014-10-17    4262.4322           4191.86  2021-03-25 12:00:15 UTC
# 2    2013-03-23    3266.5680           3080.71  2016-09-09 23:34:15 UTC
# 3    2016-08-03   21241.5424          19461.56  2022-12-28 07:58:24 UTC
# 4    2012-10-24   13335.6966          13197.54  2013-12-20 22:20:00 UTC
#
#    valor_transacao
# 0          2814.67
# 1          4191.86
# 2          3080.71
# 3         19461.56
# 4         13197.54

# %%
# Garantir que a data de abertura está em formato de data (sem hora) para ordenar
df_final['data_abertura'] = pd.to_datetime(df_final['data_abertura']).dt.tz_localize(None).dt.normalize()
df_final.head()
# Out:
#    num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0        382          382            1               77         PF
# 1          6            6            1               42         PF
# 2        242          242            1               23         PF
# 3        620          620            1               42         PF
# 4        146          146            1               67         PF
#
#   data_abertura  saldo_total  saldo_disponivel   data_ultimo_lancamento  \
# 0    2010-02-02    6992.4200           6935.26  2017-02-22 12:18:12 UTC
# 1    2010-03-09   14236.2664          13407.48  2016-10-02 22:42:28 UTC
# 2    2010-05-06  165102.0639         163409.68  2019-08-09 23:42:11 UTC
# 3    2010-06-21   29814.9465          28876.55  2014-01-29 19:49:43 UTC
# 4    2010-06-27   10975.1911          11304.70  2014-03-23 07:15:00 UTC
#
#    valor_transacao primeiro_nome ultimo_nome     nome_completo
# 0          6935.26         Luiza       Silva       Luiza Silva
# 1         13407.48     Ana Lívia       Souza   Ana Lívia Souza
# 2        163409.68        Pietra     da Rosa    Pietra da Rosa
# 3         28876.55          Juan   Fernandes    Juan Fernandes
# 4         11304.70        Kaique   das Neves  Kaique das Neves

# %%
# Ordenar: Clientes mais antigos primeiro
df_final = df_final.sort_values(by='data_abertura', ascending=True)
df_final.head()
# Out:
#    num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0        382          382            1               77         PF
# 1          6            6            1               42         PF
# 2        242          242            1               23         PF
# 3        620          620            1               42         PF
# 4        146          146            1               67         PF
#
#   data_abertura  saldo_total  saldo_disponivel   data_ultimo_lancamento  \
# 0    2010-02-02    6992.4200           6935.26  2017-02-22 12:18:12 UTC
# 1    2010-03-09   14236.2664          13407.48  2016-10-02 22:42:28 UTC
# 2    2010-05-06  165102.0639         163409.68  2019-08-09 23:42:11 UTC
# 3    2010-06-21   29814.9465          28876.55  2014-01-29 19:49:43 UTC
# 4    2010-06-27   10975.1911          11304.70  2014-03-23 07:15:00 UTC
#
#    valor_transacao primeiro_nome ultimo_nome     nome_completo
# 0          6935.26         Luiza       Silva       Luiza Silva
# 1         13407.48     Ana Lívia       Souza   Ana Lívia Souza
# 2        163409.68        Pietra     da Rosa    Pietra da Rosa
# 3         28876.55          Juan   Fernandes    Juan Fernandes
# 4         11304.70        Kaique   das Neves  Kaique das Neves

# %%
import pandas as pd

# The df_final DataFrame, as per the current kernel state, already contains 'primeiro_nome' and 'ultimo_nome'.
# Therefore, the merge with 'clientes' to get these columns is redundant and causes the MergeError.
# We will remove the merge and directly create 'nome_completo' from the existing columns.

# Create 'nome_completo' directly from existing columns
# Ensure these columns exist before attempting to create 'nome_completo'
if 'primeiro_nome' in df_final.columns and 'ultimo_nome' in df_final.columns:
    df_final['nome_completo'] = df_final['primeiro_nome'].astype(str) + ' ' + df_final['ultimo_nome'].astype(str)
else:
    print("As colunas 'primeiro_nome' ou 'ultimo_nome' não foram encontradas em df_final.")
    print("Por favor, verifique se o DataFrame df_final está no estado esperado com essas colunas.")

# 2. Agora vamos garantir que a data de abertura está no formato correto (sem hora)
df_final['data_abertura'] = pd.to_datetime(df_final['data_abertura'], errors='coerce').dt.date

# 3. Ordenar pelos mais antigos
df_final = df_final.sort_values(by='data_abertura', ascending=True)

# 4. Agora o print vai funcionar!
print("--- RELAÇÃO: ANTIGUIDADE vs VOLUME DE TRANSAÇÕES ---")
# Selecionamos apenas as colunas que queremos ver
colunas_para_exibir = ['nome_completo', 'data_abertura', 'valor_transacao']
print(df_final[colunas_para_exibir].head(50))
# Out:
# --- RELAÇÃO: ANTIGUIDADE vs VOLUME DE TRANSAÇÕES ---
#                nome_completo data_abertura  valor_transacao
# 0                Luiza Silva    2010-02-02          6935.26
# 1            Ana Lívia Souza    2010-03-09         13407.48
# 2             Pietra da Rosa    2010-05-06        163409.68
# 3             Juan Fernandes    2010-06-21         28876.55
# 4           Kaique das Neves    2010-06-27         11304.70
# 5               Daniel Gomes    2010-08-10         17130.82
# 6        Maria Sophia da Paz    2010-08-14         71851.76
# 7     Pedro Henrique da Mota    2010-10-04         10769.58
# 8             Esther Peixoto    2010-11-12          8414.48
# 9          Ana Vitória Lopes    2010-12-02          6390.18
# 10      Vitor Hugo Gonçalves    2010-12-10         22164.99
# 11              Davi Freitas    2011-02-02         40881.44
# 12              Diego da Paz    2011-02-03         87482.30
# 13           Clara Fernandes    2011-02-05         29533.51
# 14          Carolina Martins    2011-03-03         65137.83
# 15       Luiz Fernando Gomes    2011-03-08         27711.57
# 16              Kevin Fogaça    2011-03-19         35288.34
# 17     Pedro Miguel Ferreira    2011-03-22         22299.44
# 18     João Guilherme Castro    2011-03-23           393.62
# 19         Benjamin Silveira    2011-04-21         16455.88
# 20       Gabrielly Fernandes    2011-04-27        115048.84
# 21               Caio Mendes    2011-05-08             0.60
# 22                Lara Pinto    2011-05-08          4510.78
# 23               Bryan Gomes    2011-05-16         29103.95
# 24       Maria Alice Moreira    2011-05-24          2814.67
# 25          Vicente da Costa    2011-06-04        151644.40
# 26         Davi Lucas Campos    2011-06-12         44058.34
# 27          Catarina Moreira    2011-08-15         33034.49
# 28             Kamilly Silva    2011-08-21         14252.92
# 29           Stella Silveira    2011-08-25         15408.80
# 30             Sarah Moreira    2011-09-09         33166.61
# 31               Daniel Melo    2011-09-22          3563.20
# 32         Vicente Gonçalves    2011-09-22         40067.48
# 33             Renan Martins    2011-11-03         38894.44
# 34               Bruno Ramos    2011-12-06         56919.71
# 35     Maria Sophia Silveira    2012-01-13            44.86
# 36          Matheus Nogueira    2012-01-20         19863.76
# 37       Enzo Gabriel Moraes    2012-02-17         40313.21
# 38  Gustavo Henrique Freitas    2012-02-20          5112.55
# 39      Carlos Eduardo Lopes    2012-02-26         41016.20
# 40             Gustavo Cunha    2012-03-03         83480.04
# 41              Clara da Luz    2012-03-12         37024.01
# 42               Bruno Porto    2012-03-16         20939.23
# 43            Clarice Novaes    2012-03-21          5493.63
# 44         Henrique Carvalho    2012-04-07         10745.11
# 45          Augusto Silveira    2012-04-15         34545.62
# 46             Agatha da Luz    2012-04-20         22071.15
# 47             Nicolas Jesus    2012-04-21         99486.45
# 48            Amanda da Mata    2012-05-03         20567.89
# 49            Vitória Santos    2012-05-05          3727.02

# %%
print(df_final.columns.tolist())
# Out:
# ['num_conta', 'cod_cliente', 'cod_agencia', 'cod_colaborador', 'tipo_conta', 'data_abertura', 'saldo_total', 'saldo_disponivel', 'data_ultimo_lancamento', 'valor_transacao', 'primeiro_nome_x', 'ultimo_nome_x', 'nome_completo', 'primeiro_nome_y', 'ultimo_nome_y', 'primeiro_nome', 'ultimo_nome']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criar o ano de abertura
df_final['ano_abertura'] = pd.to_datetime(df_final['data_abertura']).dt.year

# Agrupar por ano e calcular volume total e ticket médio
analise_safra = df_final.groupby('ano_abertura').agg({
    'valor_transacao': ['sum', 'mean', 'count'],
    'nome_completo': 'count'
}).reset_index()

analise_safra.columns = ['Ano', 'Volume_Total', 'Ticket_Medio', 'Num_Transacoes', 'Qtd_Clientes']

# Visualização para o Relatório
plt.figure(figsize=(12, 6))
sns.barplot(data=analise_safra, x='Ano', y='Volume_Total', palette='winter')
plt.title('Volume Financeiro por Safra de Cliente (Ano de Abertura)')
plt.show()
# Out:
# /tmp/ipython-input-907024870.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=analise_safra, x='Ano', y='Volume_Total', palette='winter')

# %%
import pandas as pd

# Garantir que a data está no formato correto e criar a coluna de Ano
transacoes['data_transacao'] = pd.to_datetime(transacoes['data_transacao'], errors='coerce')
transacoes['ano_transacao'] = transacoes['data_transacao'].dt.year.fillna(0).astype(int)

# Vamos ver o Valor Total e a Quantidade de Transações por Ano
planilha_resumo = transacoes.groupby('ano_transacao').agg({
    'valor_transacao': ['sum', 'count', 'mean']
}).reset_index()

# Renomear as colunas para ficarem profissionais
planilha_resumo.columns = ['Ano', 'Volume_Total', 'Qtd_Transacoes', 'Ticket_Medio']

# 3. Ordenar do ano mais recente para o mais antigo
planilha_resumo = planilha_resumo.sort_values(by='Ano', ascending=False)

print("--- RESUMO DE TRANSAÇÕES POR ANO ---")
print(planilha_resumo)
# Out:
# --- RESUMO DE TRANSAÇÕES POR ANO ---
#      Ano  Volume_Total  Qtd_Transacoes  Ticket_Medio
# 14  2023       3501.60               8    437.700000
# 13  2022    5982048.95           23158    258.314576
# 12  2021     978014.02            7776    125.773408
# 11  2020    3396454.91            5783    587.317121
# 10  2019    3329166.68            5428    613.332108
# 9   2018    2492200.71            3944    631.896732
# 8   2017    2665821.73            3554    750.090526
# 7   2016     940687.20            2604    361.247005
# 6   2015    1050124.90            1897    553.571376
# 5   2014    1067907.72            1502    710.990493
# 4   2013     850661.15            1249    681.073779
# 3   2012     723934.39             734    986.286635
# 2   2011     416235.09             367   1134.155559
# 1   2010      28666.50              93    308.241935
# 0      0    1780028.85           13902    128.041206

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar o estilo do gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))

# Criar o gráfico de barras (Volume Total)
ax = sns.barplot(data=planilha_resumo, x='Ano', y='Volume_Total', palette='Blues_d')

# Adicionar uma linha para o Ticket Médio (Eixo secundário)
ax2 = ax.twinx()
sns.lineplot(data=planilha_resumo, x=range(len(planilha_resumo)), y='Ticket_Medio',
             color='orange', marker='o', ax=ax2, label='Ticket Médio')

# Customização de títulos e legendas
ax.set_title('Evolução Financeira BanVic: Volume Total vs. Ticket Médio', fontsize=16, fontweight='bold')
ax.set_xlabel('Ano de Transação', fontsize=12)
ax.set_ylabel('Volume Total (R$)', fontsize=12)
ax2.set_ylabel('Ticket Médio (R$)', fontsize=10)

# Adicionar rótulos de valor nas barras para facilitar a leitura
for p in ax.patches:
    ax.annotate(f'R${p.get_height():,.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3271473769.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=planilha_resumo, x='Ano', y='Volume_Total', palette='Blues_d')

# %%
from google.colab import files

# Salva a planilha que criamos
planilha_resumo.to_excel('Relatorio_BanVic_Final.xlsx', index=False)

# Faz o download automático para sua pasta 'Downloads'
files.download('Relatorio_BanVic_Final.xlsx')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Garantir que temos a coluna de ano de abertura
df_final['ano_abertura'] = pd.to_datetime(df_final['data_abertura']).dt.year

# 2. Contar quantos clientes únicos entraram por ano
# Usamos nunique() para garantir que não contamos o mesmo cliente duas vezes
novos_clientes = df_final.groupby('ano_abertura')['nome_completo'].nunique().reset_index()
novos_clientes.columns = ['Ano', 'Qtd_Novos_Clientes']

# 3. Criar o gráfico de linha
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Linha com marcadores circulares
sns.lineplot(data=novos_clientes, x='Ano', y='Qtd_Novos_Clientes',
             marker='o', markersize=8, color='forestgreen', linewidth=2.5)

# 4. Ajustar os eixos para mostrar todos os anos corretamente
plt.xticks(novos_clientes['Ano'], rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 5. Adicionar rótulos de dados (número exato de clientes sobre os pontos)
for x, y in zip(novos_clientes['Ano'], novos_clientes['Qtd_Novos_Clientes']):
    plt.text(x, y + (y*0.02), f'{int(y)}', ha='center', va='bottom',
             fontsize=9, fontweight='bold', color='darkgreen')

plt.title('Ritmo de Aquisição de Novos Clientes por Ano', fontsize=14, fontweight='bold')
plt.xlabel('Ano de Abertura de Conta', fontsize=12)
plt.ylabel('Quantidade de Novos Clientes', fontsize=12)

plt.tight_layout()
plt.show()

# %%
novos_clientes['Base_Acumulada'] = novos_clientes['Qtd_Novos_Clientes'].cumsum()
print(novos_clientes[['Ano', 'Qtd_Novos_Clientes', 'Base_Acumulada']])
# Out:
#      Ano  Qtd_Novos_Clientes  Base_Acumulada
# 0   2010                  11              11
# 1   2011                  24              35
# 2   2012                  32              67
# 3   2013                  47             114
# 4   2014                  48             162
# 5   2015                  66             228
# 6   2016                  74             302
# 7   2017                  95             397
# 8   2018                 102             499
# 9   2019                 113             612
# 10  2020                 112             724
# 11  2021                 132             856
# 12  2022                 138             994

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# --- Reconstrução de df_final para clareza e para evitar problemas de merge passados ---
# Iniciar com contas e volume_por_conta
# Isso é o que df_final se tornou após Yy859ZCq2jyT
df_temp = pd.merge(contas, volume_por_conta, on='num_conta', how='left')
df_temp['valor_transacao'] = df_temp['valor_transacao'].fillna(0) # Clientes sem transação = 0

# Agora mesclar os detalhes do cliente (nomes e data_nascimento)
# Mesclar clientes para obter 'primeiro_nome', 'ultimo_nome', 'data_nascimento'
df_temp = pd.merge(df_temp, clientes[['cod_cliente', 'primeiro_nome', 'ultimo_nome', 'data_nascimento']],
                   on='cod_cliente', how='left')

# Criar 'nome_completo'
df_temp['nome_completo'] = df_temp['primeiro_nome'].astype(str) + ' ' + df_temp['ultimo_nome'].astype(str)

# Garantir que 'data_abertura' esteja correta (do dataframe contas, já em df_temp)
df_temp['data_abertura'] = pd.to_datetime(df_temp['data_abertura'], errors='coerce').dt.date

# Ordenar por 'data_abertura'
df_temp = df_temp.sort_values(by='data_abertura', ascending=True)

# Atribuir a df_final
df_final = df_temp
# --- Fim da Reconstrução ---

# 1. Calcular a idade atual
hoje = datetime.now()
df_final['data_nascimento'] = pd.to_datetime(df_final['data_nascimento'], errors='coerce')
df_final['idade'] = df_final['data_nascimento'].apply(lambda x: hoje.year - x.year - ((hoje.month, hoje.day) < (x.month, x.day)) if pd.notna(x) else None)

# 2. Criar as faixas etárias
bins = [0, 18, 25, 35, 45, 60, 100]
labels = ['Sub-18', '18-25', '26-35', '36-45', '46-60', '60+']
df_final['faixa_etaria'] = pd.cut(df_final['idade'], bins=bins, labels=labels, right=False)

# 3. Classificar quem é Antigo (ex: conta antes de 2018) e Novo (após 2018)
# df_final['data_abertura'] já é do tipo data a partir da reconstrução
df_final['ano_abertura'] = pd.to_datetime(df_final['data_abertura']).dt.year
df_final['tipo_cliente'] = df_final['ano_abertura'].apply(lambda x: 'Antigo (Até 2017)' if x <= 2017 else 'Novo (Pós 2018)')

print(df_final[['nome_completo', 'data_nascimento', 'idade', 'faixa_etaria', 'tipo_cliente']].head())
# Out:
#        nome_completo data_nascimento  idade faixa_etaria       tipo_cliente
# 93       Luiza Silva      1962-02-16   63.0          60+  Antigo (Até 2017)
# 55   Ana Lívia Souza      1943-04-24   82.0          60+  Antigo (Até 2017)
# 23    Pietra da Rosa      2001-03-21   24.0        18-25  Antigo (Até 2017)
# 56    Juan Fernandes      1988-02-16   37.0        36-45  Antigo (Até 2017)
# 73  Kaique das Neves      1995-10-26   30.0        26-35  Antigo (Até 2017)

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Gráfico de contagem por faixa etária separado por tipo de cliente
ax = sns.countplot(data=df_final, x='faixa_etaria', hue='tipo_cliente', palette='viridis')

# Personalização
plt.title('Perfil Demográfico: Clientes Antigos vs. Novos', fontsize=14, fontweight='bold')
plt.xlabel('Faixa Etária', fontsize=12)
plt.ylabel('Quantidade de Clientes', fontsize=12)
plt.legend(title='Segmento')

# Adicionar números sobre as barras
for p in ax.patches:
    if p.get_height() > 0:
        ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 7), textcoords='offset points', fontsize=9)

plt.tight_layout()
plt.show()
